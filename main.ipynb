# %%
from generate_df import AllVerificationResults
from generate_df import GroundTruthTemplate
from check_all import Solver

# %%
verification_results_dir = './verification_results'

benchmarks_dir = './benchmarks'

# %%
all_verification_results = AllVerificationResults(verification_results_dir, benchmarks_dir)

print(all_verification_results().to_string())
# Out:
#                      benchmark                                                                                                                                      model_path                                                                                property_path abcrown_result         abcrown_time  abcrown_true debona_result         debona_time  debona_true marabou_result         marabou_time  marabou_true marabou0_result       marabou0_time  marabou0_true mip_result            mip_time  mip_true mnbab_result          mnbab_time  mnbab_true nnenum_result         nnenum_time  nnenum_true peregrinn_result      peregrinn_time  peregrinn_true
# ...

# %%
ground_truth_template = GroundTruthTemplate(verification_results_dir, benchmarks_dir)

print(ground_truth_template().to_string())
# Out:
#                      benchmark                                                                                                                                      model_path                                                                                property_path  ground_truth
# 0                       acasxu                                                                                       ./benchmarks/acasxu/onnx/ACASXU_run2a_1_1_batch_2000.onnx                                                     ./benchmarks/acasxu/vnnlib/prop_1.vnnlib           NaN
# 1                       acasxu                                                                                       ./benchmarks/acasxu/onnx/ACASXU_run2a_1_2_batch_2000.onnx                                                     ./benchmarks/acasxu/vnnlib/prop_1.vnnlib           NaN
# ...
